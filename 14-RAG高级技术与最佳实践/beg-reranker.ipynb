# %%
from modelscope import snapshot_download
model_dir = snapshot_download('BAAI/bge-reranker-large', cache_dir='/home/breeze/Documents/workspace/zhihui/code/models')
# Out:
# ...
# 2025-08-24 13:28:04,161 - modelscope - INFO - Got 11 files, start to download ...
# Processing 11 items:   0%|          | 0.00/11.0 [00:00<?, ?it/s]
# ...
# 2025-08-24 13:56:06,539 - modelscope - INFO - Download model 'BAAI/bge-reranker-large' successfully.

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('//home/breeze/Documents/workspace/zhihui/code/models/BAAI/bge-reranker-large')
model = AutoModelForSequenceClassification.from_pretrained('//home/breeze/Documents/workspace/zhihui/code/models/BAAI/bge-reranker-large')
model.eval()
