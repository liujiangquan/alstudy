# %%
import os
import asyncio
import requests
from typing import Optional
import dashscope
from qwen_agent.agents import Assistant
from qwen_agent.gui import WebUI
import pandas as pd
from sqlalchemy import create_engine
from qwen_agent.tools.base import BaseTool, register_tool
from dotenv import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/qwen_agent/gui/gradio.py:4
#       3     assert gr.__version__ >= '4.0'
# ----> 4     import modelscope_studio as mgr  # noqa
#       5 except Exception as e:
#
# File ~/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/modelscope_studio/__init__.py:1
# ----> 1 from .components.antd.components import *
#       2 from .components.antdx.components import *
#
# File ~/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/modelscope_studio/components/antd/__init__.py:145
#     144 from .typography.title import AntdTypographyTitle as TypographyTitle
# --> 145 from .upload import AntdUpload as Upload
#     146 from .upload.dragger import AntdUploadDragger as UploadDragger
#
# File ~/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/modelscope_studio/components/antd/upload/__init__.py:13
#      12 from gradio.utils import NamedString
# ---> 13 from gradio_client import handle_file
#      15 from ....utils.dev import ModelScopeDataLayoutComponent, resolve_frontend_dir
#
# ImportError: cannot import name 'handle_file' from 'gradio_client' (/home/breeze/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/gradio_client/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 7
#       5 import dashscope
#       6 from qwen_agent.agents import Assistant
# ----> 7 from qwen_agent.gui import WebUI
#       8 import pandas as pd
#       9 from sqlalchemy import create_engine
#
# File ~/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/qwen_agent/gui/__init__.py:1
# ----> 1 from qwen_agent.gui.gradio import gr, mgr
#       2 from qwen_agent.gui.web_ui import WebUI
#       4 __all__ = [
#       5     'gr',
#       6     'mgr',
#       7     'WebUI',
#       8 ]
#
# File ~/Documents/zhihui/code/alstudy/.venv/lib/python3.11/site-packages/qwen_agent/gui/gradio.py:6
#       4     import modelscope_studio as mgr  # noqa
#       5 except Exception as e:
# ----> 6     raise ImportError('The dependencies for GUI support are not installed. '
#       7                       'Please install the required dependencies by running: pip install "qwen-agent[gui]"') from e
#
# ImportError: The dependencies for GUI support are not installed. Please install the required dependencies by running: pip install "qwen-agent[gui]"
